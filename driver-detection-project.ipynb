# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/state-farm-distracted-driver-detection/driver_imgs_list.csv
# /kaggle/input/state-farm-distracted-driver-detection/sample_submission.csv
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_21286.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_14752.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_21527.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_8832.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_80739.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_71790.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_17454.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_44770.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_61144.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_89740.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_76247.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_30529.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_69655.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_100339.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_40560.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_26837.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_93555.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_63750.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_84880.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_76108.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_97541.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_30007.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_47186.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_17322.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_16359.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_79003.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_477.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_80475.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_45874.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_57770.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_14597.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_5236.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_78349.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_39868.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_65021.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_43143.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_51233.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_90603.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_84629.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_64994.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_21510.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_89883.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_62877.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_91027.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_44411.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_38969.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_19943.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_73586.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_38593.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_84368.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_42148.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_6899.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_87607.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_99188.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_88535.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_99007.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_40366.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_74516.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_62420.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_80852.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_97271.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_61110.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_45187.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_26122.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_100979.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_37896.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_4592.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_25864.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_58723.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_9103.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_98061.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_86857.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_71680.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_73517.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_14187.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_24249.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_96628.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_13791.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_89368.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_18860.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_40982.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_24849.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_30170.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_98946.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_25895.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_11441.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_23156.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_36971.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_10062.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_59255.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_60432.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_1819.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_48271.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_13742.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_53891.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_27867.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_42392.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_79135.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_41820.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_40547.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_65086.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_63915.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_26392.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_62624.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_101208.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_94131.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_41863.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_43138.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_79948.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_86656.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_98186.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_85819.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_72479.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_39940.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_96950.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_75917.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_92105.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_41378.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_95067.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_47911.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_68738.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_23297.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_47731.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_98031.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_96913.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_78062.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_93903.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_59908.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_33399.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_53334.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_16512.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_12206.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_62089.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_37367.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_43920.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_76052.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_56930.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_98826.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_47375.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_40777.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_100749.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_101741.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_77421.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_69323.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_71347.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_25740.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_50828.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_48324.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_38391.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_77359.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_98718.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_101216.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_28704.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_45000.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_2631.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_99184.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_13329.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_50531.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_2995.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_93756.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_91585.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_58781.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_57251.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_1076.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_57834.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_57996.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_58803.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_90965.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_100281.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_32808.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_15230.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_10096.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_68634.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_46089.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_76312.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_48129.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_73235.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_41900.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_36909.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_94344.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_36299.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_6220.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_3357.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_70008.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_72963.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_100048.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_100374.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_53623.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_86554.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_39465.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_84735.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_89903.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_60468.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_32870.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_50738.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_17511.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_56276.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_88026.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_31731.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_19024.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_96114.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_49269.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_14358.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_101063.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_23244.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_2178.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_66907.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_27485.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_35445.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_6196.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_98126.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_32160.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_83446.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_12717.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_44697.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_56831.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_9100.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_73623.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_14671.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_58292.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_69503.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_91906.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_55487.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_33917.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_97062.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_40181.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_34940.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_44737.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_1455.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_35905.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_89562.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_37444.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_29014.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_48460.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_8276.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_61125.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_26861.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_40342.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_4135.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_46654.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_69667.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_94722.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_9546.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_51251.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_63175.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_6835.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_74168.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_19992.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_36089.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_86509.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_74204.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_39678.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_92248.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_33994.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_39363.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_16521.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_31719.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_75034.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_40875.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_92335.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_1783.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_25891.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_41086.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_67821.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_101685.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_96864.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_69452.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_44021.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_6132.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_31862.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_22012.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_30791.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_36150.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_30212.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_34001.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_18429.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_35732.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_58279.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_54289.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_24776.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_40140.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_87171.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_18145.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_27636.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_8635.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_24008.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_77562.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_70705.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_43857.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_39259.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_78178.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_98242.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_27273.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_37189.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_30514.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_72310.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_8155.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_14384.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_204.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_11603.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_18746.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_56045.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_57570.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_72989.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_5289.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_100328.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_34712.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_26054.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_61346.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_7574.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_60973.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_74112.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_65012.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_84246.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_65308.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_13412.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_35548.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_24878.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_2284.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_533.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_94343.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_87732.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_65524.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_22859.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_14304.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_26985.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_34510.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_70379.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_28393.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_77122.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_73192.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_8084.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_71295.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_63179.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_44312.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_68558.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_32323.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_67516.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_74430.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_100041.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_59173.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_97427.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_99703.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_20694.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_28140.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_59270.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_1342.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_12426.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_27140.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_39288.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_43425.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_55546.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_38098.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_77335.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_24487.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_82715.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_101118.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_89257.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_15879.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_16924.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_17550.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_11352.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_30070.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_92901.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_43168.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_100414.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_15717.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_70627.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_88171.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_34078.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_28685.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_58768.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_40857.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_98052.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_94562.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_64858.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_95957.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_44716.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_6556.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_21975.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_15575.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_80688.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_63127.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_88690.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_98935.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_91849.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_12070.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_50731.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_59334.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_21620.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_99406.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_18760.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_35790.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_88881.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_7017.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_57205.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_44546.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_35236.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_49283.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_15274.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_15132.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_28119.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_90742.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_41505.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_16407.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_96401.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_64898.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_94232.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_27859.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_32997.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_53574.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_51458.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_2034.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_36761.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_68978.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_80292.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_101059.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_37240.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_88895.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_43399.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_43646.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_67160.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_35956.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_28316.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_38470.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_53246.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_94970.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_9157.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_86815.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_51480.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_99480.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_18085.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_43648.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_89971.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_67591.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_7798.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_14229.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_20805.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_66717.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_61328.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_42551.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_4778.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_99712.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_63304.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_7097.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_42751.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_78515.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_9858.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_91729.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_57628.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_65043.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_43927.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_36736.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_37107.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_33293.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_3040.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_86194.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_20113.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_65026.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_86162.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_1153.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_28432.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_510.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_26873.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_80807.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_1286.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_87327.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_83354.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_62421.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_11162.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_44408.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_71852.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_27556.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_47284.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_56857.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_87304.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_86219.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_58002.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_33875.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_38074.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_49494.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_37427.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_81984.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_3392.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_20673.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_18390.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_85545.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_60719.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_41038.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_77066.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_30666.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_80493.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_4727.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_16256.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_8557.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_91769.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_101163.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_70869.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_53902.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_15506.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_16548.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_58967.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_77882.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_68600.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_78611.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_7093.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_95494.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_100927.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_73046.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_63355.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_32553.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_49942.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_40965.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_54688.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_67362.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_23528.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_71904.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_32285.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_84545.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_78790.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_68776.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_28942.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_39800.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_99947.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_29491.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_19687.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_20406.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_12674.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_14283.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_2558.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_31910.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_4144.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_39740.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_60136.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_97182.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_73781.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_99374.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_50402.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_60891.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_26058.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_46508.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_12591.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_9853.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_38733.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_5034.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_27011.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_32418.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_34408.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_41685.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_30431.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_65989.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_41984.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_86863.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_79164.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_23883.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_11813.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_26196.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_68507.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_26152.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_9604.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_42641.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_25900.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_17979.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_59937.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_37947.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_24069.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_25072.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_67502.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_25100.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_83041.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_78904.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_80587.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_20748.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_72416.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_32697.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_67985.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_29533.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_71619.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_32021.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_43787.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_62204.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_98185.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_93713.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_44764.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_102064.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_95218.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_57439.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_37756.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_34609.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_37806.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c3/img_88520.jpg
# ...
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_85428.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_61778.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_1906.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_82910.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_25847.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_86620.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_92108.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_46799.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_79991.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_54065.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_91303.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_47039.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_52381.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_48138.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_81615.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_81690.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_84726.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_96378.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_101610.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_32955.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_31437.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_43086.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_53264.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_59580.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_19516.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_79544.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_49571.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_88416.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_86190.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_20333.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_92820.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_14206.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_90661.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_6672.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_17540.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_68294.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_82510.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_1071.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_94293.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_59296.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_92297.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_70402.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_50130.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_7192.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_37299.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_40065.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_83921.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_33850.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_66152.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_33468.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_91628.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_62225.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_18122.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_77815.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_54209.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_73652.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_14364.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_50294.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_69623.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_23572.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_92503.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_92511.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_12736.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_38349.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_80110.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_48804.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_78665.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_72.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_20121.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_26418.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_42913.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_77816.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_16493.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_69390.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_48975.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_2957.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_3629.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_4322.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_85290.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_56373.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_38398.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_95818.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_94319.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_68537.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_29978.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_53555.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_19438.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_52208.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_75120.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_53182.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_4875.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_21461.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_38476.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_31131.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_48904.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_29610.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_27911.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_10777.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_85418.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_25860.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_31303.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_1602.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_23414.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_21400.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_91445.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_5297.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_90814.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_49684.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_49719.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_41103.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_19986.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_26104.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_57988.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_96807.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_79721.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_22245.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_63264.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_63886.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_66165.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_4198.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_6945.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_100144.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_34375.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_97302.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_25207.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_7597.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_30869.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_42874.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_37072.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_80274.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_16901.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_81755.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_89117.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_56751.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_26246.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_87915.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_58055.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_28165.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_66433.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_17122.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_678.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_3320.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_30185.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_99697.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_5806.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_40075.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_53347.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_88058.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_73812.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_51995.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_59329.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_60437.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_101252.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_86579.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_67542.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_58117.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_74263.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_47226.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_73826.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_5271.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_53621.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_85282.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_51367.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_28697.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_42480.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_55894.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_7216.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_58037.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_97294.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_34440.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_71950.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_9704.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_45277.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_88578.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_13740.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_14553.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_19657.jpg
# /kaggle/input/state-farm-distracted-driver-detection/imgs/train/c6/img_44798.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-04ff0c20c54e> in <module>
#      10
#      11 import os
# ---> 12 for dirname, _, filenames in os.walk('/kaggle/input'):
#      13     for filename in filenames:
#      14         print(os.path.join(dirname, filename))
#
# /opt/conda/lib/python3.7/os.py in walk(top, topdown, onerror, followlinks)
#     409             # above.
#     410             if followlinks or not islink(new_path):
# --> 411                 yield from walk(new_path, topdown, onerror, followlinks)
#     412     else:
#     413         # Recurse into sub-directories
#
# /opt/conda/lib/python3.7/os.py in walk(top, topdown, onerror, followlinks)
#     409             # above.
#     410             if followlinks or not islink(new_path):
# --> 411                 yield from walk(new_path, topdown, onerror, followlinks)
#     412     else:
#     413         # Recurse into sub-directories
#
# /opt/conda/lib/python3.7/os.py in walk(top, topdown, onerror, followlinks)
#     409             # above.
#     410             if followlinks or not islink(new_path):
# --> 411                 yield from walk(new_path, topdown, onerror, followlinks)
#     412     else:
#     413         # Recurse into sub-directories
#
# /opt/conda/lib/python3.7/os.py in walk(top, topdown, onerror, followlinks)
#     358             try:
#     359                 try:
# --> 360                     entry = next(scandir_it)
#     361                 except StopIteration:
#     362                     break
#
# KeyboardInterrupt:

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2
import glob

#DATA
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import one_hot
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split

#for CNN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Convolution2D,MaxPooling2D,Flatten,Dense
from keras.optimizers import Adam
from keras.losses import CategoricalCrossentropy

#VIS
from keras.utils.vis_utils import plot_model

# %%
#Preprocessing data
def _prepareData(path): 
    '''
    parameters: path(STR) of the directory and flag(INT) to know if we prepare data of training or testing
    return: (LIST) of images of the dataset and the (LIST) of labels
    
    For training:
    -Read images of every directory and extract all images
    -Resize to (128,128,3)
    -Read the directory name and asign as a class
    '''
    imgsList = []
    labels = []
    for directory in sorted(glob.glob(os.path.join(path, '*')), key = lambda k: k.split("/")[-1]):
            for imgs in glob.glob(os.path.join(directory,'*.jpg')):
                img_cv = cv2.imread(imgs)
                img_cv_r = cv2.resize(img_cv,(128,128))
                imgsList.append(img_cv_r)
                labels.append(int(directory.split("/")[-1].replace('c','')))
    
    X_Train, X_Test, Y_Train, Y_Test =  train_test_split(imgsList,labels, test_size = 0.2)
    Y_Train = tf.keras.utils.to_categorical(Y_Train, num_classes=10)
    Y_Test = tf.keras.utils.to_categorical(Y_Test, num_classes=10)

    return np.array(X_Train), np.array(X_Test), Y_Train, Y_Test

# %%
#Get Data

#Paths
pathTrain_Images = "/kaggle/input/state-farm-distracted-driver-detection/imgs/train/"
pathPropagate_Images =  "/kaggle/input/state-farm-distracted-driver-detection/imgs/test/"

#List of Images for Train and Test
X_Train, X_Test, Y_Train, Y_Test = _prepareData(pathTrain_Images)

print("Size X_Train: {}, Size Y_Train: {}".format(len(X_Train),len(Y_Train)))
print("Size X_Test: {}, Size Y_Test: {}".format(len(X_Test),len(Y_Test)))

# %%
print(len(X_Train))
print(X_Train[202].shape)

#change the image to grayscale format for less computational expenses.
im = X_Train[202]
RGB_im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_im)
plt.show()
print("Class: {}".format(Y_Train[202]))

# %%
#Creating CNN architecture
model = keras.models.Sequential()  #sequential model

#Add all the layers 
model.add(keras.layers.InputLayer(
    input_shape=(128, 128, 3)
))

model.add(
    keras.layers.Conv2D(
        filters=32,
        kernel_size=(5,5),
        strides = (1,1),
        padding='same',
        activation='relu',
        name='Conv_1'))

model.add(
    keras.layers.MaxPool2D(
        pool_size = (2,2),
        name = 'Pool_1'))#Image_size: 32*64*64(32 filters,image_size 64*64)

model.add(
    keras.layers.Conv2D(
        filters = 64,
        kernel_size = (5,5),
        strides = (1,1),
        padding = 'same',
        activation = 'relu',
        name = 'Conv_2'))

model.add(
    keras.layers.MaxPool2D(
        pool_size = (2,2),
        name = 'Pool_2'))#Image_size: 64*32*32(64 filters,image_size 32*32)

model.add(
    keras.layers.Conv2D(
        filters = 128,
        kernel_size = (5,5),
        strides = (1,1),
        padding = 'same',
        activation = 'relu',
        name = 'Conv_3'))

model.add(
    keras.layers.MaxPool2D(
        pool_size = (2,2),
        name = 'Pool_3'))#Image_size: 128*16*16(128 filters,image_size 16*16)

model.add(
    keras.layers.Conv2D(
        filters = 256,
        kernel_size = (5,5),
        strides = (1,1),
        padding = 'same',
        activation = 'relu',
        name = 'Conv_4'))

model.add(
    keras.layers.MaxPool2D(
        pool_size = (2,2),
        name = 'Pool_4'))#Image_size: 256*8*8(256 filters,image_size 8*8)

#Flattening the images to an array
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(units=1024, activation='relu',name = 'fc_1'))
model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.Dense(units=512, activation='relu',name = 'fc_2'))
model.add(keras.layers.Dense(units=10,activation='softmax',name = 'fc_3'))
model.save('/tmp/model')
#model.compute_output_shape(input_shape=(256,8,8,1))

# %%
#Compiling the model

tf.random.set_seed(1)
#model.build(input_shape=(None,128,128,3))
model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.CategoricalCrossentropy(from_logits = False), metrics = ['accuracy'])
print(model.summary())

# %%
#Training the model
history = model.fit(x = X_Train, y = Y_Train,epochs = 10, batch_size = 500, verbose = 1,validation_split=0.2)

# %%
#Evaluate model with test data
test_loss, test_acc = model.evaluate(X_Test, Y_Test, verbose = 1)

# %%
#Predict Test data and create a submission file
df = pd.DataFrame({'img':[],'c0':[], 'c1':[],'c2':[], 'c3':[], 'c4':[],'c5':[], 'c6':[], 'c7':[], 'c8':[], 'c9':[]})
def _submission(pathPropagate_Images,df):
    for imgs in glob.glob(os.path.join(pathPropagate_Images,'*.jpg')):
        img_cv = cv2.imread(imgs)
        img_cv_r = cv2.resize(img_cv,(128,128))
        img_cv_predict = np.reshape(img_cv_r,[1,128,128,3])
        arr_predict = model.predict(img_cv_predict,batch_size = 1)
        #print(imgs.split('/')[-1])
        df = df.append(
            {
                'img':imgs.split('/')[-1],
                'c0':round(arr_predict[0][0],2), 
                'c1':round(arr_predict[0][1],2),
                'c2':round(arr_predict[0][2],2),
                'c3':round(arr_predict[0][3],2),
                'c4':round(arr_predict[0][4],2),
                'c5':round(arr_predict[0][5],2),
                'c6':round(arr_predict[0][6],2),
                'c7':round(arr_predict[0][7],2),
                'c8':round(arr_predict[0][8],2),
                'c9':round(arr_predict[0][9],2)
            },
            ignore_index=True
        )
    return df

# %%
#creating dataframe of values
pathPropagate_Images =  "/kaggle/input/state-farm-distracted-driver-detection/imgs/test/"
df = _submission(pathPropagate_Images,df)

# %%
print(df.shape)
df.head(50)

# %%
#Save submission file
df.to_csv('submission_file.csv',index = False)
